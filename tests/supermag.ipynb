# %%
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import torch
import numpy as np
from datetime import datetime
import os

# %%
def load_geomag_data(netcdf_path: str) -> xr.Dataset:
    """Load geomagnetic data from a NetCDF file."""
    try:
        print("loading raw data...")
        ds = xr.open_dataset(netcdf_path, chunks="auto")
        print(ds)
        return ds
    except Exception as e:
        raise RuntimeError(f"Error loading NetCDF file {netcdf_path}: {e}")

geomag_path = r"D:\earthquake-prediction\data\geomagnetic_data\supermag\all_stations_all2024.netcdf"
ds = load_geomag_data(geomag_path)
# Out:
# loading raw data...
# <xarray.Dataset> Size: 7GB
# Dimensions:  (block: 527040, vector: 201)
# Dimensions without coordinates: block, vector
# Data variables: (12/23)
#     dbe_geo  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbe_nez  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbn_geo  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbn_nez  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbz_geo  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbz_nez  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     ...       ...
#     time_dy  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_hr  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_mo  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_mt  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_sc  (block) float64 4MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_yr  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
# Attributes:
#     description:  For the ground magnetometer data we gratefully acknowledge:...

# %%
def assign_time_as_coordinate(ds: xr.Dataset) -> xr.Dataset:
    time_as_datetime = pd.to_datetime({
        "year": ds["time_yr"].values,
        "month": ds["time_mo"].values,
        "day": ds["time_dy"].values,
        "hour": ds["time_hr"].values,
        "minute": ds["time_mt"].values
    })


    ds = ds.assign_coords(time=("block", time_as_datetime))
    ds = ds.drop_vars(["time_yr", "time_mo", "time_dy", "time_hr", "time_mt", "time_sc"])
    ds = ds.swap_dims({"block": "time"})
    
    return ds


ds = assign_time_as_coordinate(ds)
print(ds)
print(ds.indexes)
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:  (time: 527040, vector: 201)
# Coordinates:
#   * time     (time) datetime64[ns] 4MB 2024-01-01 ... 2024-12-31T23:59:00
# Dimensions without coordinates: vector
# Data variables: (12/17)
#     dbe_geo  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbe_nez  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbn_geo  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbn_nez  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbz_geo  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbz_nez  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     ...       ...
#     mcolat   (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     mlat     (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     mlon     (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     mlt      (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     npnt     (time) int32 2MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     sza      (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
# Attributes:
#     description:  For the ground magnetometer data we gratefully acknowledge:...
# Indexes:
#     time     DatetimeIndex(['2024-01-01 00:00:00', '2024-01-01 00:01:00',
#                '2024-01-01 00:02:00', '2024-01-01 00:03:00',
#                '2024-01-01 00:04:00', '2024-01-01 00:05:00',
#                '2024-01-01 00:06:00', '2024-01-01 00:07:00',
#                '2024-01-01 00:08:00', '2024-01-01 00:09:00',
#                ...
#                '2024-12-31 23:50:00', '2024-12-31 23:51:00',
#                '2024-12-31 23:52:00', '2024-12-31 23:53:00',
#                '2024-12-31 23:54:00', '2024-12-31 23:55:00',
#                '2024-12-31 23:56:00', '2024-12-31 23:57:00',
#                '2024-12-31 23:58:00', '2024-12-31 23:59:00'],
#               dtype='datetime64[ns]', name='time', length=527040, freq=None)

# %%
print(ds["id"].isel(time=0).values)
# Out:
# ['AAA' 'ABG' 'ABK' 'AIA' 'AND' 'API' 'ARS' 'ASC' 'ASP' 'BDV' 'BEL' 'BFE'
#  'BFO' 'BJN' 'BLC' 'BMT' 'BOU' 'BRD' 'BRW' 'BSL' 'C03' 'C04' 'C05' 'C06'
#  'C09' 'C13' 'CBB' 'CKI' 'CLF' 'CMO' 'CNB' 'CPS' 'CSY' 'CTA' 'CYG' 'DAW'
#  'DED' 'DLT' 'DMH' 'DOB' 'DON' 'DOU' 'DUR' 'EAG' 'EBR' 'ESK' 'EYR' 'FCC'
#  'FMC' 'FRD' 'FRN' 'FSP' 'FUR' 'FYU' 'GAK' 'GAN' 'GCK' 'GDH' 'GIM' 'GLK'
#  'GNG' 'GUA' 'GUI' 'HAD' 'HAN' 'HBK' 'HER' 'HLP' 'HOB' 'HON' 'HOP' 'HOV'
#  'HRB' 'HRN' 'HUA' 'IPM' 'IQA' 'IRT' 'ISL' 'IVA' 'JAI' 'JAN' 'JCK' 'KAG'
#  'KAK' 'KAR' 'KDU' 'KEP' 'KEV' 'KHB' 'KIL' 'KIR' 'KMH' 'KNY' 'KOU' 'KTB'
#  'KUV' 'LER' 'LON' 'LRM' 'LRV' 'LVV' 'LYC' 'LYR' 'MAB' 'MAS' 'MAW' 'MCM'
#  'MCQ' 'MEA' 'MEK' 'MGD' 'MMB' 'MSR' 'MUO' 'NAL' 'NAQ' 'NCK' 'NEW' 'NGK'
#  'NOR' 'NR2' 'NUR' 'NVS' 'ORC' 'OTT' 'OUJ' 'PAF' 'PAG' 'PEG' 'PEL' 'PET'
#  'PHU' 'PIL' 'PIN' 'PKR' 'PPT' 'PST' 'RAL' 'RAN' 'RES' 'RIK' 'ROE' 'RVK'
#  'SBA' 'SBL' 'SHE' 'SHU' 'SIT' 'SJG' 'SKT' 'SMI' 'SOD' 'SOL' 'SOR' 'SPA'
#  'SPT' 'STF' 'STJ' 'SUA' 'T03' 'T39' 'T43' 'T49' 'T50' 'T51' 'T52' 'T55'
#  'T62' 'TAL' 'TAM' 'TAR' 'TDC' 'THL' 'THY' 'TOP' 'TSU' 'TTB' 'TUC' 'TWN'
#  'UPS' 'VAL' 'VIC' 'VNA' 'VOS' 'VSS' 'WIC' 'WNG' 'WSE' 'Y01' 'Y02' 'Y08'
#  'Y09' 'Y10' 'Y12' 'Y13' 'Y14' 'Y15' 'Y16' 'Y17' 'YKC']

# %%
print(ds.dtype)
# Out:
# object

# %%
import cupy as cp

ds = ds.isel(vector=0)
ds = ds.to_array().unify_chunks()
ds = ds.map_blocks(cp.asarray)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\xarray\core\parallel.py:127, in infer_template(func, obj, *args, **kwargs)
#     126 try:
# --> 127     template = func(*meta_args, **kwargs)
#     128 except Exception as e:
#
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\cupy\_creation\from_data.py:88, in asarray(a, dtype, order, blocking)
#      57 """Converts an object to array.
#      58
#      59 This is equivalent to ``array(a, dtype, copy=False, order=order)``.
#    (...)
#      86
#      87 """
# ---> 88 return _core.array(a, dtype, False, order, blocking=blocking)
#
# File cupy\\_core\\core.pyx:2455, in cupy._core.core.array()
#
# File cupy\\_core\\core.pyx:2482, in cupy._core.core.array()
#
# File cupy\\_core\\core.pyx:2621, in cupy._core.core._array_default()
#
# ValueError: Unsupported dtype object
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[15], line 5
#       3 ds = ds.isel(vector=0)
#       4 ds = ds.to_array().unify_chunks()
# ----> 5 ds = ds.map_blocks(cp.asarray)
#
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\xarray\core\dataarray.py:5593, in DataArray.map_blocks(self, func, args, kwargs, template)
#    5495 """
#    5496 Apply a function to each block of this DataArray.
#    5497
#    (...)
#    5589     month    (time) int64 192B dask.array<chunksize=(24,), meta=np.ndarray>
#    5590 """
#    5591 from xarray.core.parallel import map_blocks
# -> 5593 return map_blocks(func, self, args, kwargs, template)
#
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\xarray\core\parallel.py:458, in map_blocks(func, obj, args, kwargs, template)
#     455 coordinates: Coordinates
#     456 if template is None:
#     457     # infer template by providing zero-shaped arrays
# --> 458     template = infer_template(func, aligned[0], *args, **kwargs)
#     459     template_coords = set(template.coords)
#     460     preserved_coord_vars = template_coords & set(merged_coordinates)
#
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\xarray\core\parallel.py:129, in infer_template(func, obj, *args, **kwargs)
#     127     template = func(*meta_args, **kwargs)
#     128 except Exception as e:
# --> 129     raise Exception(
#     130         "Cannot infer object returned from running user provided function. "
#     131         "Please supply the 'template' kwarg to map_blocks."
#     132     ) from e
#     134 if not isinstance(template, Dataset | DataArray):
#     135     raise TypeError(
#     136         "Function must return an xarray DataArray or Dataset. Instead it returned "
#     137         f"{type(template)}"
#     138     )
#
# Exception: Cannot infer object returned from running user provided function. Please supply the 'template' kwarg to map_blocks.

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\xarray\core\parallel.py:127, in infer_template(func, obj, *args, **kwargs)
#     126 try:
# --> 127     template = func(*meta_args, **kwargs)
#     128 except Exception as e:
#
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\cupy\_creation\from_data.py:88, in asarray(a, dtype, order, blocking)
#      57 """Converts an object to array.
#      58
#      59 This is equivalent to ``array(a, dtype, copy=False, order=order)``.
#    (...)
#      86
#      87 """
# ---> 88 return _core.array(a, dtype, False, order, blocking=blocking)
#
# File cupy\\_core\\core.pyx:2455, in cupy._core.core.array()
#
# File cupy\\_core\\core.pyx:2482, in cupy._core.core.array()
#
# File cupy\\_core\\core.pyx:2621, in cupy._core.core._array_default()
#
# ValueError: Unsupported dtype object
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import cupy as cp
#       3 ds = ds.unify_chunks()
# ----> 4 ds = ds.isel(vector=0).map_blocks(cp.asarray)
#
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\xarray\core\dataarray.py:5593, in DataArray.map_blocks(self, func, args, kwargs, template)
#    5495 """
#    5496 Apply a function to each block of this DataArray.
#    5497
#    (...)
#    5589     month    (time) int64 192B dask.array<chunksize=(24,), meta=np.ndarray>
#    5590 """
#    5591 from xarray.core.parallel import map_blocks
# -> 5593 return map_blocks(func, self, args, kwargs, template)
#
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\xarray\core\parallel.py:458, in map_blocks(func, obj, args, kwargs, template)
#     455 coordinates: Coordinates
#     456 if template is None:
#     457     # infer template by providing zero-shaped arrays
# --> 458     template = infer_template(func, aligned[0], *args, **kwargs)
#     459     template_coords = set(template.coords)
#     460     preserved_coord_vars = template_coords & set(merged_coordinates)
#
# File c:\Users\DELL\anaconda3\envs\DL\Lib\site-packages\xarray\core\parallel.py:129, in infer_template(func, obj, *args, **kwargs)
#     127     template = func(*meta_args, **kwargs)
#     128 except Exception as e:
# --> 129     raise Exception(
#     130         "Cannot infer object returned from running user provided function. "
#     131         "Please supply the 'template' kwarg to map_blocks."
#     132     ) from e
#     134 if not isinstance(template, Dataset | DataArray):
#     135     raise TypeError(
#     136         "Function must return an xarray DataArray or Dataset. Instead it returned "
#     137         f"{type(template)}"
#     138     )
#
# Exception: Cannot infer object returned from running user provided function. Please supply the 'template' kwarg to map_blocks.

# %%
print(ds[[ "dbn_nez", "dbe_nez", "dbz_nez", "glat", "glon"]].isel(block=1, vector=1).compute())
# Out:
# <xarray.Dataset> Size: 20B
# Dimensions:  ()
# Data variables:
#     dbn_nez  float32 4B 4.452
#     dbe_nez  float32 4B 1.046
#     dbz_nez  float32 4B -0.7833
#     glat     float32 4B 18.62
#     glon     float32 4B 72.87
# Attributes:
#     description:  For the ground magnetometer data we gratefully acknowledge:...

# %%
print(ds.data_vars)
# Out:
# Data variables:
#     dbe_geo  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbe_nez  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbn_geo  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbn_nez  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbz_geo  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbz_nez  (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     decl     (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     extent   (block) float64 4MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     glat     (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     glon     (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     id       (block, vector) <U3 1GB dask.array<chunksize=(172073, 65), meta=np.ndarray>
#     mcolat   (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     mlat     (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     mlon     (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     mlt      (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     npnt     (block) int32 2MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     sza      (block, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     time_dy  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_hr  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_mo  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_mt  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_sc  (block) float64 4MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     time_yr  (block) int16 1MB dask.array<chunksize=(527040,), meta=np.ndarray>

# %%
start_time = {"time_yr": 2024, "time_mo": 1, "time_dy": 1, "time_hr": 0, "time_mt": 0}  # Start: Jan 1, 2025, 00:00
end_time = {"time_yr": 2024, "time_mo": 1, "time_dy": 7, "time_hr": 0, "time_mt": 0}    # End: Jan 2, 2025, 00:00

# Step 1: Select variables of interest
selected_vars = ds[["dbn_nez", "dbe_nez", "dbz_nez", "glat", "glon"]]


time_mask = (
    (ds["time_yr"] >= start_time["time_yr"]) & (ds["time_yr"] <= end_time["time_yr"]) &
    (ds["time_mo"] >= start_time["time_mo"]) & (ds["time_mo"] <= end_time["time_mo"]) &
    (ds["time_dy"] >= start_time["time_dy"]) & (ds["time_dy"] <= end_time["time_dy"]) 
    # (ds["time_hr"] >= start_time["time_hr"]) & (ds["time_hr"] <= end_time["time_hr"]) &
    # (ds["time_mt"] >= start_time["time_mt"]) & (ds["time_mt"] <= end_time["time_mt"])
).compute()

# Step 3: Apply the time mask
selected_data = selected_vars.where(time_mask, drop=True)
# Step 4: Compute the selection (load into memory)
final_data = selected_data.sel(vector=0).compute()

# Step 5: Print the result
print(final_data)
# Out:
# <xarray.Dataset> Size: 202kB
# Dimensions:  (block: 10080)
# Dimensions without coordinates: block
# Data variables:
#     dbn_nez  (block) float32 40kB 4.957 4.903 4.831 4.864 ... 8.531 8.304 8.188
#     dbe_nez  (block) float32 40kB 2.935 2.933 2.732 ... -2.593 -2.682 -2.68
#     dbz_nez  (block) float32 40kB -2.558 -2.558 -2.559 ... -3.162 -3.26 -3.263
#     glat     (block) float32 40kB 43.25 43.25 43.25 43.25 ... 43.25 43.25 43.25
#     glon     (block) float32 40kB 76.92 76.92 76.92 76.92 ... 76.92 76.92 76.92
# Attributes:
#     description:  For the ground magnetometer data we gratefully acknowledge:...

# %%
def filter_data_by_time(ds: xr.Dataset, start_time: pd.Timestamp, end_time: pd.Timestamp) -> xr.DataArray:
    """
    Filters an xarray dataset based on a given time range.
    
    Parameters:
        ds (xr.Dataset): The dataset containing time-related variables.
        start_time (pd.Timestamp): The start time for filtering.
        end_time (pd.Timestamp): The end time for filtering.
    
    Returns:
        xr.DataArray: The filtered dataset with the specified time range applied.
    """
    # Step 1: Select variables of interest
    selected_vars = ds[["dbn_nez", "dbe_nez", "dbz_nez", "glat", "glon"]]

    # Step 2: Create a time mask based on the extracted time components
    time_mask = (
        (ds["time_yr"] >= start_time.year) & (ds["time_yr"] <= end_time.year) &
        (ds["time_mo"] >= start_time.month) & (ds["time_mo"] <= end_time.month) &
        (ds["time_dy"] >= start_time.day) & (ds["time_dy"] <= end_time.day)
        # (ds["time_hr"] >= start["time_hr"]) & (ds["time_hr"] <= end["time_hr"]) &
        # (ds["time_mt"] >= start["time_mt"]) & (ds["time_mt"] <= end["time_mt"])
    ).compute()

    # Step 3: Apply the time mask
    selected_data = selected_vars.where(time_mask, drop=True)

    # Step 4: Compute the selection (load into memory)
    final_data = selected_data.sel(vector=0).compute()

    return final_data

start_time = pd.Timestamp("2024-01-01 00:00:00")
end_time = pd.Timestamp("2024-01-07 00:00:00")

# Assuming `ds` is your xarray dataset
filtered_result = filter_data_by_time(ds, start_time, end_time)

# Print the result
print(filtered_result)
# Out:
# <xarray.Dataset> Size: 202kB
# Dimensions:  (block: 10080)
# Dimensions without coordinates: block
# Data variables:
#     dbn_nez  (block) float32 40kB 4.957 4.903 4.831 4.864 ... 8.531 8.304 8.188
#     dbe_nez  (block) float32 40kB 2.935 2.933 2.732 ... -2.593 -2.682 -2.68
#     dbz_nez  (block) float32 40kB -2.558 -2.558 -2.559 ... -3.162 -3.26 -3.263
#     glat     (block) float32 40kB 43.25 43.25 43.25 43.25 ... 43.25 43.25 43.25
#     glon     (block) float32 40kB 76.92 76.92 76.92 76.92 ... 76.92 76.92 76.92
# Attributes:
#     description:  For the ground magnetometer data we gratefully acknowledge:...

# %%
'''
for each station k:

    #func 1 get positives
    eq_periods: List[Tuple[datetime, datetime]]
    for each eq in catalog:
        if eq in range:
            eq_periods.append((eq.time - timeperiod, eq.time))
    
            
    #func 2 get negatives, since eq_periods are sorted
    start_time = year/1/1 00:00:00
    end_time = start_time + timeperiod
    eq_index = 0
    normal_periods = List[Tuple[datetime, datetime]]
    while end_time < year+1/1/1 00:00:00:
        if end_time <= eq_periods[eq_index].first:
            period is normal, normal_periods.append((start_time, end_time))
            start_time = end_time
            end_time = start_time + timeperiod
        else:
            eq_index += 1
            start_time = eq_periods[eq_index].second
            end_time = start_time + timeperiod
    
    extract_geomag(station=k, eq_periods)
    extract_geomag(station=k, normal_periods)
            

'''

# %%
import xarray as xr
import pandas as pd
from haversine import haversine_vector, Unit
import numpy as np

# %%
def get_station_coords(geomag: xr.Dataset) -> np.ndarray:
    glats = geomag["glat"].isel(block=0).values
    glons = geomag["glon"].isel(block=0).values

    coords = np.stack((glats, glons), axis=-1)
    return coords


def normalize_coordinates_batch(coords: np.ndarray) -> np.ndarray:

    assert coords.shape[1] == 2, f"Invalid shape: {coords.shape}, expected (N, 2)"
    
    # Extract latitude and longitude
    lat, lon = coords[:, 0], coords[:, 1]

    # Validate latitude (raises error if out of range)
    if np.any((lat < -90) | (lat > 90)):
        raise ValueError("Latitude values must be between -90 and 90.")

    # Normalize longitude to range [-180, 180] using vectorized modulo operation
    lon = ((lon + 180) % 360) - 180

    # Return new array with normalized values
    return np.column_stack((lat, lon))


def get_eq_periods_for_station(
        station_coord: np.ndarray, 
        catalog: pd.DataFrame, 
        time_period: pd.Timedelta, 
        radius: float) -> np.ndarray:
    
    station_coord = normalize_coordinates_batch(station_coord.reshape(1, 2))[0]

    coords = np.stack((catalog["latitude"].values, catalog["longitude"].values), axis=1)
    # print(coords)
    coords = normalize_coordinates_batch(coords)
    
    distances = haversine_vector(coords, station_coord, unit=Unit.KILOMETERS, comb=True )[0]  # Fast haversine distance
    # print(distances)
    mask = distances <= radius
    # print(mask)
    filtered_eqs = catalog.loc[mask]
    filtered_eqs = pd.to_datetime(filtered_eqs["time"], format="%Y-%m-%dT%H:%M:%S.%fZ", utc=True)

    # Compute time windows efficiently
    eq_periods = np.column_stack([
        (filtered_eqs - time_period).values,  # Start times
        filtered_eqs.values  # End times
    ])

    return eq_periods


def get_normal_periods_for_station(
        year: int,
        eq_periods: list[tuple[pd.Timestamp, pd.Timestamp]],
        time_period: pd.Timedelta,
        ) -> np.ndarray:
    
    start_time = pd.Timestamp(year=year, month=1, day=1, hour=0, minute=0, second=0)
    end_of_year = pd.Timestamp(year=year+1, month=1, day=1, hour=0, minute=0, second=0)

    normal_periods = []
    
    eq_index = 0
    end_time = start_time + time_period

    while end_time < end_of_year:
        if eq_index < len(eq_periods) and end_time <= eq_periods[eq_index][0]:  
            # No overlap, normal period
            normal_periods.append([start_time, end_time])
            start_time = end_time
            end_time = start_time + time_period
        elif eq_index < len(eq_periods):
            # Overlap detected, move start_time to after the earthquake period
            start_time = eq_periods[eq_index][1]
            end_time = start_time + time_period
            eq_index += 1  # Move to the next earthquake period
        else:
            # No more earthquakes, fill in remaining normal periods
            normal_periods.append([start_time, end_time])
            start_time = end_time
            end_time = start_time + time_period  

    return np.array(normal_periods, dtype=object)

# %%
catalog = pd.read_csv(r"D:\earthquake-prediction\data\catalog\csv\usgs\2024.csv")
# needs function that extracts the coordinates for each station
station_coords = get_station_coords(ds)
time_period = pd.Timedelta(days=7)
radius = 200
year = 2024

dataset_ranges_by_station = np.empty((0, 2), dtype=object)
# iterate through each station
for station_coord in station_coords:
    
    # get earthquake periods for station
    eq_periods = get_eq_periods_for_station(
        station_coord=station_coord, 
        catalog=catalog, 
        time_period=time_period, 
        radius=radius)
    # get normal periods for station
    normal_periods = get_normal_periods_for_station(
        eq_periods=eq_periods,
        time_period=time_period, 
        year=year)
    
    print(f"Station: {station_coord}")
    print(f"Earthquake periods: {eq_periods.shape}")
    print(f"Normal periods: {normal_periods.shape}\n")

    station_samples = np.array([normal_periods, eq_periods], dtype=object)
    print(station_samples.shape)
    dataset_ranges_by_station = np.vstack([dataset_ranges_by_station, station_samples])

print(f"Dataset shape: {dataset_ranges_by_station.shape}")
# Out:
# [16058.26460867  9215.43814982  9092.46640075 ...  5021.83967847
#   5041.58618265  5039.5674001 ]
# [False False False ... False False False]
# Station: [43.25 76.92]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [16189.86430991  8962.30748442  8973.32457885 ...  6490.33910363
#   6529.43764217  6527.50236207]
# [False False False ... False False False]
# Station: [18.62 72.87]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12064.69202844 12298.95748935 12054.2917633  ...  7219.38979841
#   7202.56355618  7201.2582046 ]
# [False False False ... False False False]
# Station: [68.35 18.82]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 5032.48540266 11525.03011201 11777.43038535 ... 16605.24032726
#  16625.11269278 16626.32299026]
# [False False False ... False False False]
# Station: [-65.245 295.742]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11971.28540296 12318.97651861 12069.38558594 ...  7237.24982177
#   7219.14330125  7217.88003849]
# [False False False ... False False False]
# Station: [69.3  16.03]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10607.80132516  4189.48237777  4155.74700279 ...  7807.1331384
#   7795.26123879  7797.20286509]
# [False False False ... False False False]
# Station: [-13.8  188.22]
# Earthquake periods: (3, 2)
# Normal periods: (55, 2)
#
# (2,)
# [14230.92328605 10748.31201824 10571.29038318 ...  5961.18606114
#   5963.08653738  5961.30033757]
# [False False False ... False False False]
# Station: [56.433 58.567]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 6188.38335769 17685.86917517 17968.64061993 ... 15656.88489263
#  15664.41317922 15662.53549485]
# [False False False ... False False False]
# Station: [ -7.949 345.624]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [14453.41573951  2606.76988726  2904.46036771 ...  6785.4214791
#   6820.7565966   6821.29259598]
# [False False False ... False False False]
# Station: [-23.77 133.88]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11311.57332071 13795.71442489 13612.01107748 ...  8894.01920221
#   8888.41182071  8886.79144124]
# [False False False ... False False False]
# Station: [49.07 14.02]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11853.12976718 13226.341151   13042.93379733 ...  8337.25145371
#   8332.64369468  8330.99892575]
# [False False False ... False False False]
# Station: [51.83 20.8 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11379.40322835 13480.47013686 13266.85254404 ...  8464.55569507
#   8454.00531161  8452.51302553]
# [False False False ... False False False]
# Station: [55.62 11.67]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10890.54104742 14177.97348912 13984.85215792 ...  9229.43681167
#   9221.70267492  9220.13578362]
# [False False False ... False False False]
# Station: [48.33  8.33]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12161.56508214 11864.36313203 11603.75805234 ...  6790.63489079
#   6769.34467997  6768.19136116]
# [False False False ... False False False]
# Station: [74.5 19.2]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9647.25420948 11786.86831091 11473.42062571 ...  7823.00859235
#   7777.76356361  7777.86837795]
# [False False False ... False False False]
# Station: [ 64.32 263.99]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [17686.06345127  6296.50147991  6111.12005086 ...  1817.65990664
#   1845.64432734  1843.60569309]
# [False False False ... False False False]
# Station: [ 40.3 116.2]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7605.97580416 11689.16056145 11412.17745979 ...  9341.31498788
#   9290.34068775  9291.17968641]
# [False False False ... False False False]
# Station: [ 40.14 254.76]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8308.71919231 11961.63042111 11662.42513701 ...  8847.91219317
#   8798.66523333  8799.18446571]
# [False False False ... False False False]
# Station: [ 49.87  260.026]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11987.88115067  9482.44537846  9171.15682432 ...  5294.3131474
#   5248.29747003  5248.46717661]
# [False False False ... False False False]
# Station: [ 71.32 203.38]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 5975.76081887 13229.30562662 12976.97762015 ... 11083.5446689
#  11033.02229469 11033.7507349 ]
# [False False False ... False False False]
# Station: [ 30.35 270.36]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9528.43222766 11120.31322563 10810.78023773 ...  7649.83841379
#   7601.19981959  7601.64070895]
# [False False False ... False False False]
# Station: [ 58.769 248.894]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8642.51992221 11371.51550296 11073.25544949 ...  8410.6930049
#   8360.61319018  8361.25820282]
# [False False False ... False False False]
# Station: [ 50.061 251.739]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8384.67051365 12215.5360584  11911.94691422 ...  8875.33338743
#   8827.10378708  8827.49718267]
# [False False False ... False False False]
# Station: [ 52.035 264.537]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9130.40785501 11029.66403511 10726.48558253 ...  7927.15964662
#   7877.21961976  7877.8411949 ]
# [False False False ... False False False]
# Station: [ 53.351 247.026]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8674.35636677 12139.2855627  11832.01847062 ...  8636.05262079
#   8588.46096603  8588.78476426]
# [False False False ... False False False]
# Station: [ 54.929 264.713]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9333.67868463 10549.07137519 10247.91226662 ...  7635.9677057
#   7585.32651357  7586.07995859]
# [False False False ... False False False]
# Station: [ 51.883 239.974]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10302.99461462 11267.50783708 10953.86129743 ...  7169.79213004
#   7125.04178585  7125.10532048]
# [False False False ... False False False]
# Station: [ 69.12 254.97]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [16163.17887546  5917.81658762  6089.12272997 ...  6897.49314186
#   6948.6937354   6947.77188725]
# [False False False ... False False False]
# Station: [-12.1875  96.8386]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10465.41703692 14528.91789195 14321.75938265 ...  9526.22421676
#   9515.77832528  9514.28406215]
# [False False False ... False False False]
# Station: [48.02  2.27]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11448.82401334  9396.65062236  9082.91690302 ...  5640.59552608
#   5591.67802987  5592.15263382]
# [False False False ... False False False]
# Station: [ 64.87 212.14]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [12561.77975722  3050.38514908  3342.81136141 ...  8056.04084539
#   8080.42614798  8081.45828124]
# [False False False ... False False False]
# Station: [-34.1 150.7]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12843.20845191  8714.989114    8407.46470244 ...  4398.14201592
#   4352.29247739  4352.44639723]
# [False False False ... False False False]
# Station: [ 68.878 180.63 ]
# Earthquake periods: (1, 2)
# Normal periods: (51, 2)
#
# (2,)
# [10400.07509588  7301.15942209  7613.4931244  ... 11723.77083289
#  11763.63036617 11763.91148182]
# [False False False ... False False False]
# Station: [-66.283 110.533]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [13997.21706972  1563.2788161   1875.92599562 ...  6447.25756007
#   6472.87710157  6473.85859107]
# [False False False ... False False False]
# Station: [-20.1 146.3]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [17539.78291902  5386.93684383  5179.3834329  ...   892.46348469
#    933.74409588   931.86957642]
# [False False False ... False False False]
# Station: [ 36.37  126.854]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11028.7080108   9739.70604873  9426.24413368 ...  6069.05870319
#   6020.0754053   6020.55867628]
# [False False False ... False False False]
# Station: [ 64.048 220.89 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11684.92485137  9661.04834902  9348.47193173 ...  5571.5292494
#   5524.92331211  5525.14750968]
# [False False False ... False False False]
# Station: [ 70.36 211.21]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [19093.58959926  5093.97677094  5091.28839639 ...  3981.50376819
#   4032.78845889  4031.6465438 ]
# [False False False ... False False False]
# Station: [ 11.94 108.48]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11313.74139503 12192.83822187 11907.08762042 ...  7228.06816871
#   7199.20780176  7198.35553124]
# [False False False ... False False False]
# Station: [ 76.77 341.37]
# Earthquake periods: (1, 2)
# Normal periods: (51, 2)
#
# (2,)
# [11463.01965887 13099.63609397 12862.00925845 ...  8027.76759372
#   8012.46814556  8011.11514697]
# [False False False ... False False False]
# Station: [62.07  9.11]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11748.9521277  12667.24488449 12422.77996587 ...  7587.86532208
#   7571.05170474  7569.74634254]
# [False False False ... False False False]
# Station: [66.11 12.5 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10716.98352821 14244.77259914 14036.07034359 ...  9239.37153442
#   9228.96273227  9227.4672022 ]
# [False False False ... False False False]
# Station: [50.1  4.6]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11067.2088184  14231.36338113 14084.72623683 ...  9509.38011497
#   9508.55698271  9506.8284228 ]
# [False False False ... False False False]
# Station: [41.39 14.28]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11153.29739224  9678.05163773  9364.40843683 ...  5955.43853589
#   5906.63363965  5907.09420608]
# [False False False ... False False False]
# Station: [ 64.78 218.84]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9979.78076826 15196.86306466 15013.11149998 ... 10268.7327642
#  10260.88900293 10259.3257718 ]
# [False False False ... False False False]
# Station: [40.82   0.493]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10509.36517863 14126.92753608 13885.43721483 ...  9050.25279526
#   9033.89405563  9032.57548994]
# [False False False ... False False False]
# Station: [ 55.32 356.8 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10468.61386033  4607.23895189  4829.25669729 ...  9653.87498867
#   9667.4029098   9668.8078501 ]
# [False False False ... False False False]
# Station: [-43.4 172.4]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9038.41844594 12080.62133993 11769.65615223 ...  8355.99701976
#   8309.49952308  8309.71534367]
# [False False False ... False False False]
# Station: [ 58.76 265.91]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9346.57399431 11128.14245002 10820.73143165 ...  7789.27828099
#   7740.14127665  7740.6453864 ]
# [False False False ... False False False]
# Station: [ 56.657 248.79 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 6530.00373831 14064.58385232 13778.29628886 ... 10928.23785141
#  10881.03125215 10881.31671449]
# [False False False ... False False False]
# Station: [ 38.2  282.63]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8185.06698896 10427.78981421 10159.04603827 ...  8615.99749341
#   8564.71647368  8565.86168251]
# [False False False ... False False False]
# Station: [ 37.09 240.28]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10148.0421873  10565.48917705 10253.68772514 ...  7001.83149562
#   6953.11200562  6953.56249471]
# [False False False ... False False False]
# Station: [ 61.756 238.77 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11088.88022344 14017.70989279 13832.02082201 ...  9102.94757139
#   9096.65887496  9095.05537422]
# [False False False ... False False False]
# Station: [48.17 11.28]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11403.58896776  9590.49881155  9276.80729145 ...  5741.19729362
#   5692.94778518  5693.34194239]
# [False False False ... False False False]
# Station: [ 66.56 214.78]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11222.38687693  9389.96368262  9076.6153275  ...  5810.7941133
#   5761.13860063  5761.71501059]
# [False False False ... False False False]
# Station: [ 62.39 214.87]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [15520.62446066  8627.99934857  8735.64828599 ...  7657.21769838
#   7704.05783395  7702.37917954]
# [False False False ... False False False]
# Station: [ 0.6946 73.1537]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11674.17068544 13597.21178969 13447.47470764 ...  8882.93204839
#   8883.13900381  8881.38862487]
# [False False False ... False False False]
# Station: [44.63 20.77]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10038.04767294 12837.87230262 12531.7063322  ...  8148.9963916
#   8113.28112491  8112.76069466]
# [False False False ... False False False]
# Station: [ 69.25 306.47]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8806.17581875 12131.45693667 11822.57375658 ...  8538.72109608
#   8491.55844185  8491.83841905]
# [False False False ... False False False]
# Station: [ 56.376 265.36 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [13542.52776012 11843.38036423 11740.14660098 ...  7583.70185795
#   7596.26871243  7594.31677458]
# [False False False ... False False False]
# Station: [40.935 44.475]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [14244.51293186  4542.84847281  4825.78032794 ...  7931.66670443
#   7975.81552327  7975.79665579]
# [False False False ... False False False]
# Station: [-31.356003 115.715   ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [16175.95284247  2339.00075577  2098.76728873 ...  2742.83364459
#   2761.86612263  2763.08260272]
# [False False False ... False False False]
# Station: [ 13.589996 144.87    ]
# Earthquake periods: (10, 2)
# Normal periods: (50, 2)
#
# (2,)
# [ 7934.11822696 17246.49799945 17035.80310844 ... 12214.57666609
#  12200.87091684 12199.47300857]
# [False False False ... False False False]
# Station: [ 28.32 343.57]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10192.62773547 14576.31602334 14342.42564396 ...  9509.18777144
#   9494.14311743  9492.78357996]
# [False False False ... False False False]
# Station: [ 50.98 355.52]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12355.71418329 12362.04425519 12144.31725864 ...  7339.21622087
#   7328.85895902  7327.36028211]
# [False False False ... False False False]
# Station: [62.25 26.6 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9827.8233299  12869.69097079 13125.22610367 ... 13332.90811982
#  13377.77988801 13376.00640151]
# [False False False ... False False False]
# Station: [-25.879997  27.71    ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8743.8478184  13165.01805214 13453.64770707 ... 14483.4001748
#  14530.42686945 14528.75617717]
# [False False False ... False False False]
# Station: [-34.43  19.23]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11788.9587254  13180.80912585 12982.72885857 ...  8225.24671978
#   8218.0103905   8216.42993799]
# [False False False ... False False False]
# Station: [54.61 18.82]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11998.32082162  4039.08152951  4338.42478674 ...  8966.77922185
#   8994.4022366   8995.30393969]
# [False False False ... False False False]
# Station: [-42.88 147.35]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10552.44966404  6412.95688113  6166.12658089 ...  6438.41563186
#   6397.2959658   6399.18904234]
# [False False False ... False False False]
# Station: [ 21.32 202.  ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12333.22793447 11602.07527976 11339.20159377 ...  6533.17461944
#   6511.06248401  6509.93878101]
# [False False False ... False False False]
# Station: [76.51 25.01]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10681.80208293 13638.05412646 13378.17729764 ...  8560.80404933
#   8540.43181709  8539.24767508]
# [False False False ... False False False]
# Station: [ 61.5 353.2]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11569.95907876 13606.62971547 13436.49431911 ...  8776.418252
#   8773.38193818  8771.70121267]
# [False False False ... False False False]
# Station: [47.86 18.19]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12098.00321678 11756.34144567 11488.25011101 ...  6700.68735359
#   6677.06409716  6675.99725543]
# [False False False ... False False False]
# Station: [77.  15.6]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 1034.43087154 14529.43354361 14523.93572395 ... 15766.43534097
#  15715.53461743 15716.81114084]
# [False False False ... False False False]
# Station: [-12.05 284.67]
# Earthquake periods: (2, 2)
# Normal periods: (81, 2)
#
# (2,)
# [ 4010.48513193 10648.1124891  10681.99003186 ... 13807.40278419
#  13774.71609983 13776.73445524]
# [False False False ... False False False]
# Station: [-27.199997 250.58    ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9334.6838404  12946.14904634 12633.0979839  ...  8570.24902086
#   8530.07654915  8529.81534227]
# [False False False ... False False False]
# Station: [ 63.75 291.48]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [16432.77352186  7861.66830696  7661.26446991 ...  3015.56112307
#   3021.13691172  3019.28049339]
# [False False False ... False False False]
# Station: [ 52.17 104.45]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8548.72979679 12211.96401354 11905.81449341 ...  8753.73000571
#   8705.99948797  8706.33798409]
# [False False False ... False False False]
# Station: [ 53.856 265.34 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12411.06069901 11997.76892108 11758.91712386 ...  6924.55398901
#   6909.29359208  6907.93821186]
# [False False False ... False False False]
# Station: [68.56 27.29]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [16522.40865687  8854.67474679  8817.71351083 ...  5765.34621082
#   5800.06866076  5798.06895518]
# [False False False ... False False False]
# Station: [26.92 75.8 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11170.13927168 12724.83840671 12450.38892574 ...  7686.71651345
#   7661.98116261  7660.95853297]
# [False False False ... False False False]
# Station: [ 70.9 351.3]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11951.70918317 12495.10802537 12254.37297204 ...  7419.32845419
#   7403.45884167  7402.12311734]
# [False False False ... False False False]
# Station: [66.4  16.98]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [17544.15250179  4737.26286626  4529.30016562 ...   846.63674211
#    897.67620381   896.8127149 ]
# [False False False ... False False False]
# Station: [ 31.48 130.72]
# Earthquake periods: (8, 2)
# Normal periods: (96, 2)
#
# (2,)
# [16531.87877096  4891.87159764  4634.65097137 ...   317.3241868
#    294.14102965   296.15803741]
# [False False False ... False False False]
# Station: [ 36.23 140.18]
# Earthquake periods: (9, 2)
# Normal periods: (50, 2)
#
# (2,)
# [11154.37794627 13476.14059529 13240.52168146 ...  8407.08682213
#   8392.10168901  8390.73929561]
# [False False False ... False False False]
# Station: [59.21  5.24]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [15572.12641327  2093.19036497  2314.43353346 ...  5564.58588286
#   5601.51535086  5601.96345199]
# [False False False ... False False False]
# Station: [-12.686 132.472]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 4759.51867737 13205.74256057 13485.18517272 ... 18047.23349029
#  18088.12069697 18088.34956309]
# [False False False ... False False False]
# Station: [-54.282 323.507]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12400.57298552 11941.58800997 11698.76578298 ...  6863.58140586
#   6847.28717204  6845.96431793]
# [False False False ... False False False]
# Station: [69.76 27.01]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [16209.5041444   6233.91579225  5978.15269711 ...  1171.79475831
#   1145.08772891  1144.11425363]
# [False False False ... False False False]
# Station: [ 47.61 134.69]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [12152.72957614 12188.62400417 11943.49372072 ...  7108.71217452
#   7091.77593527  7090.47402314]
# [False False False ... False False False]
# Station: [69.06 20.77]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12122.9950875  12279.75101088 12037.90347017 ...  7202.73858145
#   7186.6360615   7185.30748435]
# [False False False ... False False False]
# Station: [67.84 20.42]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8901.57809201 13702.97788616 13973.02002108 ... 14207.63301084
#  14250.49055586 14248.64536404]
# [False False False ... False False False]
# Station: [-26.54  18.11]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [17533.09341884  4723.83449824  4515.33671277 ...   842.07428982
#    893.00043742   892.17044768]
# [False False False ... False False False]
# Station: [ 31.42  130.882]
# Earthquake periods: (8, 2)
# Normal periods: (96, 2)
#
# (2,)
# [ 3434.50421399 17432.56270296 17311.77830667 ... 15197.36792941
#  15155.61980409 15155.46772779]
# [False False False ... False False False]
# Station: [  5.209999 307.27    ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [17543.47230055  5620.77473657  5716.73654862 ...  5597.71546281
#   5649.05743127  5647.97313145]
# [False False False ... False False False]
# Station: [ -0.2  100.32]
# Earthquake periods: (1, 2)
# Normal periods: (51, 2)
#
# (2,)
# [10579.77719165 12256.93735153 11952.87407641 ...  7544.7162531
#   7508.90062594  7508.38499892]
# [False False False ... False False False]
# Station: [ 74.57 302.82]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10870.53782686 13615.04543782 13366.66418148 ...  8533.71961327
#   8515.95710601  8514.68374636]
# [False False False ... False False False]
# Station: [ 60.13 358.82]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11384.50631819 13843.36814545 13681.8144826  ...  9052.24470055
#   9050.09058227  9048.39039772]
# [False False False ... False False False]
# Station: [45.4081 16.6592]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [15395.1614717   4144.29157128  4382.49444276 ...  6862.87053962
#   6908.85450087  6908.68280094]
# [False False False ... False False False]
# Station: [-21. 115.]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10274.94626917 13590.41425603 13307.40376594 ...  8586.41691665
#   8560.08341277  8559.12575569]
# [False False False ... False False False]
# Station: [ 64.18 338.3 ]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [12015.7029511  13141.37991731 12971.19489552 ...  8323.75627019
#   8321.6296842   8319.92836379]
# [False False False ... False False False]
# Station: [49.9  23.75]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11997.47027543 12552.40285618 12318.81756295 ...  7487.61369999
#   7473.449892    7472.06143582]
# [False False False ... False False False]
# Station: [64.61 18.75]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12122.14741256 11661.12163226 11390.62374294 ...  6614.30952627
#   6589.84965398  6588.81499301]
# [False False False ... False False False]
# Station: [78.2  15.83]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10796.3204264  14174.37205152 13967.49839245 ...  9175.48072499
#   9165.45756507  9163.95138525]
# [False False False ... False False False]
# Station: [50.3   5.68]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12271.39655907 12068.35809697 11824.22029957 ...  6989.17945661
#   6972.5168365   6971.20594316]
# [False False False ... False False False]
# Station: [69.46 23.7 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9543.23483247  9224.69939194  9538.41719536 ... 13160.44629345
#  13206.92281364 13206.70981608]
# [False False False ... False False False]
# Station: [-67.605  62.882]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8525.44520649  7970.20050714  8253.8261202  ... 12949.09647302
#  12977.43267181 12978.30787583]
# [False False False ... False False False]
# Station: [-77.85 166.67]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10470.30576264  5371.38583896  5648.64666661 ... 10412.6510128
#  10436.46942416 10437.52574748]
# [False False False ... False False False]
# Station: [-54.5  158.95]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [ 9254.11482835 11002.52525087 10697.63207375 ...  7822.05821819
#   7772.31689794  7772.90703762]
# [False False False ... False False False]
# Station: [ 54.616 246.653]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12581.33546289 12135.10743597 11919.28069317 ...  7120.06719607
#   7110.37133305  7108.854371  ]
# [False False False ... False False False]
# Station: [62.77 30.97]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [14520.56890136  7409.80459169  7119.03316248 ...  2722.19097634
#   2679.09815889  2679.02694425]
# [False False False ... False False False]
# Station: [ 59.97 150.86]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [15856.7276678   5660.51371812  5384.69853242 ...   971.48668316
#    921.37345069   922.01507587]
# [False False False ... False False False]
# Station: [ 43.91 144.19]
# Earthquake periods: (4, 2)
# Normal periods: (86, 2)
#
# (2,)
# [15964.97062384  5735.92265855  5464.56210155 ...   920.09099546
#    872.54638432   872.84623402]
# [False False False ... False False False]
# Station: [ 44.37 142.27]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [12254.23681071 12161.20678647 11921.31878529 ...  7086.53075382
#   7070.95581454  7069.6104478 ]
# [False False False ... False False False]
# Station: [68.02 23.53]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12050.97513739 11664.70020226 11391.24380067 ...  6630.12344209
#   6604.71340298  6603.7162662 ]
# [False False False ... False False False]
# Station: [78.92 11.95]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9321.39003877 13811.40745561 13505.12290751 ...  9077.19663983
#   9043.24801716  9042.63655297]
# [False False False ... False False False]
# Station: [ 61.16 314.56]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11457.18879717 13714.40062096 13542.50702416 ...  8872.15989648
#   8868.63149377  8866.96202994]
# [False False False ... False False False]
# Station: [47.63 16.72]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8902.42111022 10730.40135417 10435.58604138 ...  8036.4968554
#   7985.58952169  7986.40900664]
# [False False False ... False False False]
# Station: [ 48.27 242.88]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11321.96688667 13676.4478126  13477.78033945 ...  8712.38300783
#   8704.37931482  8702.81896466]
# [False False False ... False False False]
# Station: [52.07 12.68]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12356.31208869 11905.31685609 11657.70531786 ...  6824.04484449
#   6806.45688156  6805.17594686]
# [False False False ... False False False]
# Station: [71.09 25.79]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12236.47972031 12546.37983728 12333.1607066  ...  7537.84416868
#   7528.30412135  7526.78336195]
# [False False False ... False False False]
# Station: [60.5  24.65]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12236.47972031 12546.37983728 12333.1607066  ...  7537.84416868
#   7528.30412135  7526.78336195]
# [False False False ... False False False]
# Station: [60.5  24.65]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [15549.58380255  9234.26174608  9051.66981154 ...  4466.36972962
#   4471.6222378   4469.77381874]
# [False False False ... False False False]
# Station: [55.03 82.9 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 4943.50492382 12401.50766289 12672.53838173 ... 17394.42597488
#  17426.02007598 17426.75891578]
# [False False False ... False False False]
# Station: [-60.737 315.26 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7309.83611161 13840.46282046 13538.35897549 ... 10274.97276383
#  10229.45998578 10229.588919  ]
# [False False False ... False False False]
# Station: [ 45.403 284.448]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12399.1040569  12215.72100388 11990.39925107 ...  7170.65159478
#   7158.6500351   7157.19743917]
# [False False False ... False False False]
# Station: [64.52 27.23]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11372.62745788  8744.73440225  9041.62342171 ... 11632.02092885
#  11682.32820173 11681.64258755]
# [False False False ... False False False]
# Station: [-49.350006  70.26    ]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [11998.47174769 13225.11493327 13067.00178697 ...  8474.59136673
#   8474.32129852  8472.58045683]
# [False False False ... False False False]
# Station: [47.49 24.18]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11756.84701477 13630.49475102 13521.35348488 ...  9184.99681005
#   9190.96963526  9189.11270058]
# [False False False ... False False False]
# Station: [38.1 23.9]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12268.95027338 12208.11572132 11972.18532665 ...  7139.39766737
#   7124.80879695  7123.43292096]
# [False False False ... False False False]
# Station: [66.9  24.08]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [14492.35874055  6670.95898912  6370.76127908 ...  2412.35366731
#   2362.38579197  2363.00859574]
# [False False False ... False False False]
# Station: [ 52.971 158.248]
# Earthquake periods: (14, 2)
# Normal periods: (79, 2)
#
# (2,)
# [19646.2105605   5762.15178858  5705.50298576 ...  3472.5016617
#   3521.41951719  3519.88475321]
# [False False False ... False False False]
# Station: [ 21.029999 105.95    ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 1346.98555926 14304.26575515 14446.29593734 ... 17868.75922443
#  17823.9193092  17825.68706509]
# [False False False ... False False False]
# Station: [-31.4  294.47]
# Earthquake periods: (2, 2)
# Normal periods: (51, 2)
#
# (2,)
# [ 8215.42361963 12228.14925694 11927.45949793 ...  9006.07458397
#   8957.40615874  8957.85119046]
# [False False False ... False False False]
# Station: [ 50.199 263.96 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11439.4663561   9427.67093631  9113.93729624 ...  5658.01855511
#   5609.1958224   5609.6584565 ]
# [False False False ... False False False]
# Station: [ 65.12 212.57]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [8229.02984889 6592.35636575 6567.0186621  ... 9803.28793596 9780.86634076
#  9782.89810139]
# [False False False ... False False False]
# Station: [-17.57 210.42]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 3675.53470595 12981.31704    13215.28110352 ... 18030.87390294
#  18038.62453484 18040.20608702]
# [False False False ... False False False]
# Station: [-51.703 302.11 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9234.85045673 11555.75245595 11246.28002028 ...  8017.54577813
#   7969.58321147  7969.94643788]
# [False False False ... False False False]
# Station: [ 58.222 256.32 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9420.83561383 12025.31345473 11712.09407819 ...  8074.89900164
#   8029.80534806  8029.89767143]
# [False False False ... False False False]
# Station: [ 62.824 267.89 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10689.58422239 11426.34801801 11115.4249706  ...  7014.53017515
#   6973.15770843  6972.97330285]
# [False False False ... False False False]
# Station: [ 74.69  265.105]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [15909.73373831  5618.32437999  5343.81331247 ...   912.85320725
#    862.66473362   863.31929225]
# [False False False ... False False False]
# Station: [ 43.48 143.76]
# Earthquake periods: (5, 2)
# Normal periods: (86, 2)
#
# (2,)
# [11176.86274326 13660.7218507  13443.02508984 ...  8631.5087091
#   8620.01554252  8618.5498373 ]
# [False False False ... False False False]
# Station: [55.17  8.55]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11647.33324737 12807.68639566 12564.66677781 ...  7729.51992109
#   7713.03829955  7711.72239006]
# [False False False ... False False False]
# Station: [64.94 10.99]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8523.35364431  7970.95047798  8254.52165124 ... 12950.23924011
#  12978.55806156 12979.43401562]
# [False False False ... False False False]
# Station: [-77.850006 166.78    ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7210.87644763 14914.93482789 14604.67179214 ... 10836.52315131
#  10795.80236956 10795.57798463]
# [False False False ... False False False]
# Station: [ 43.932 299.991]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 6834.34302192 16391.87870206 16676.6295591  ... 15649.31067681
#  15672.54851304 15670.51439004]
# [False False False ... False False False]
# Station: [-15.95 354.27]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11830.90044972  8231.01101557  7918.26746035 ...  5023.64524483
#   4972.44011656  4973.36365754]
# [False False False ... False False False]
# Station: [ 55.35 199.54]
# Earthquake periods: (3, 2)
# Normal periods: (69, 2)
#
# (2,)
# [10463.42936956  9685.15347857  9375.82869138 ...  6496.77445322
#   6446.22028019  6446.95454897]
# [False False False ... False False False]
# Station: [ 57.06 224.67]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [ 4285.80870725 15838.74920247 15619.07348379 ... 13411.39369678
#  13364.52078312 13364.77481279]
# [False False False ... False False False]
# Station: [ 18.11 293.85]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [ 9636.91266099 13230.21612182 12922.15360227 ...  8574.32460885
#   8538.39541345  8537.88686071]
# [False False False ... False False False]
# Station: [ 65.42 307.1 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9667.63018434 11065.43952003 10754.86752656 ...  7528.0112458
#   7479.61100166  7480.02349437]
# [False False False ... False False False]
# Station: [ 60.03 248.07]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12381.45286393 12086.72193141 11851.25343845 ...  7018.90539856
#   7004.4821882   7003.10111616]
# [False False False ... False False False]
# Station: [67.37 26.63]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11212.86233017 13333.06181989 13091.93234538 ...  8256.77090014
#   8240.63387019  8239.30747807]
# [False False False ... False False False]
# Station: [61.08  4.84]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12223.28305698 12047.95053299 11799.63478697 ...  6966.46280934
#   6948.68438329  6947.40990654]
# [False False False ... False False False]
# Station: [70.54 22.22]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7763.35148709  9266.163781    9557.21690102 ... 14142.84645427
#  14175.9714672  14176.62751824]
# [False False False ... False False False]
# Station: [-90.   0.]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9551.49782976 15582.93702614 15386.90446437 ... 10605.2725698
#  10595.22710957 10593.7227338 ]
# [False False False ... False False False]
# Station: [ 39.55 355.65]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9836.0474579  13111.71607456 12805.51651508 ...  8409.81781341
#   8374.60303933  8374.05628213]
# [False False False ... False False False]
# Station: [ 67.02 309.28]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7747.09352611 14957.67455679 14643.94079022 ... 10540.33333618
#  10502.94100441 10502.51497473]
# [False False False ... False False False]
# Station: [ 47.595 307.323]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12111.7154247  13171.05904805 13026.86962359 ...  8509.89133356
#   8511.99643343  8510.20824104]
# [False False False ... False False False]
# Station: [45.32 26.25]
# Earthquake periods: (1, 2)
# Normal periods: (51, 2)
#
# (2,)
# [ 8875.81068597 11034.62795708 10736.10826045 ...  8132.28161522
#   8081.87355019  8082.57840338]
# [False False False ... False False False]
# Station: [ 50.367 247.02 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11472.15231023  9141.60918802  8828.02966721 ...  5542.17437653
#   5492.38323258  5492.98027795]
# [False False False ... False False False]
# Station: [ 62.24 209.58]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8978.82839712 10941.29430884 10641.94736337 ...  8024.494903
#   7974.06534088  7974.77440797]
# [False False False ... False False False]
# Station: [ 50.87 245.7 ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7840.13533383 14089.74447968 13778.03203451 ... 10035.19617987
#   9993.21380771  9993.07309217]
# [False False False ... False False False]
# Station: [ 50.22 293.73]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7655.99969753 13847.25449813 13539.30802104 ... 10041.46550855
#   9997.37861051  9997.39138358]
# [False False False ... False False False]
# Station: [ 48.65 287.55]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7620.63033109 13547.97767785 13243.35494051 ...  9935.98323456
#   9890.38687426  9890.52280589]
# [False False False ... False False False]
# Station: [ 48.05 282.22]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 8252.74423136 13232.09212615 12921.52758829 ...  9371.83767558
#   9327.40521345  9327.44467135]
# [False False False ... False False False]
# Station: [ 53.79 282.38]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11455.7670157   9006.7230411   8693.43501133 ...  5516.74870073
#   5466.50160899  5467.17533758]
# [False False False ... False False False]
# Station: [ 60.554 208.742]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12366.54988291 12175.52835694 11944.7741524  ...  7117.0884821
#   7103.79792236  7102.38289073]
# [False False False ... False False False]
# Station: [65.9  26.41]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10141.84702716 11685.17500269 11371.85528381 ...  7463.88522634
#   7420.70103973  7420.64397284]
# [False False False ... False False False]
# Station: [ 69.54 266.45]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9539.16157921 15867.8176142  15817.67490937 ... 11621.14900812
#  11625.90485644 11624.06997146]
# [False False False ... False False False]
# Station: [22.79  5.53]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12314.91436354 12572.51376634 12369.93217405 ...  7605.24703683
#   7597.93939154  7596.36020506]
# [False False False ... False False False]
# Station: [58.26 26.46]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 5897.10658284 14833.35735345 15146.60052304 ... 17291.84005746
#  17335.70920396 17333.89447955]
# [False False False ... False False False]
# Station: [-37.1  347.69]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [10858.87558796 11808.16218561 11503.18250382 ...  7141.83018254
#   7104.70382061  7104.25981375]
# [False False False ... False False False]
# Station: [ 77.47 290.77]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11495.02145446 13702.09042094 13535.19050922 ...  8886.39045175
#   8883.68758936  8881.99945354]
# [False False False ... False False False]
# Station: [46.9  17.54]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11484.81023177 13374.48481654 13161.76933055 ...  8362.14987459
#   8351.8761341   8350.376121  ]
# [False False False ... False False False]
# Station: [56.092 13.178]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9115.91921625 14106.92546438 14352.18890995 ... 13833.78841361
#  13872.24776782 13870.2984261 ]
# [False False False ... False False False]
# Station: [-19.217  17.7  ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 3198.02448954 17722.78116103 17701.23478486 ... 15976.48200463
#  15937.40772748 15937.08639229]
# [False False False ... False False False]
# Station: [ -1.205 311.487]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 7218.17628128 11218.24266694 10965.44971674 ...  9597.00403444
#   9545.68492177  9546.80037405]
# [False False False ... False False False]
# Station: [ 32.17 249.27]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [14024.83852706  1459.00846035  1771.24445108 ...  6364.83132231
#   6389.88601574  6390.8899143 ]
# [False False False ... False False False]
# Station: [-19.27 146.82]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11827.82688148 12921.59334852 12701.79602592 ...  7889.60243547
#   7878.29498382  7876.8233413 ]
# [False False False ... False False False]
# Station: [59.9  17.35]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9915.19668598 14684.2476574  14433.86113052 ...  9602.58325287
#   9584.45683475  9583.19658201]
# [False False False ... False False False]
# Station: [ 51.93 349.75]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9257.74541848 10269.65917211  9973.76419017 ...  7637.64961332
#   7586.51389108  7587.40773109]
# [False False False ... False False False]
# Station: [ 48.52 236.58]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 6892.3289117  11268.56726691 11571.50373179 ... 15774.11202564
#  15817.64306364 15817.67783493]
# [False False False ... False False False]
# Station: [-70.7 351.7]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 9046.49320538  8348.27875271  8653.14110463 ... 13010.04721717
#  13047.3988478  13047.83027691]
# [False False False ... False False False]
# Station: [-78.45  106.867]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 2801.71242679 16430.92936734 16637.13406557 ... 18369.95847517
#  18335.1526595  18334.60648942]
# [False False False ... False False False]
# Station: [-22.4  316.35]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11368.28604956 13795.74219642 13621.81760774 ...  8941.12351368
#   8937.11551739  8935.45716786]
# [False False False ... False False False]
# Station: [47.55 15.52]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [11153.7117994  13743.11390714 13531.23392962 ...  8731.08036379
#   8720.60664085  8719.11246778]
# [False False False ... False False False]
# Station: [53.75  9.07]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [12664.99739446 11874.58441029 11646.37788392 ...  6822.85293804
#   6810.38445107  6808.9449646 ]
# [False False False ... False False False]
# Station: [66.552 33.1  ]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 1298.58012351 14002.01751845 14133.63456271 ... 17556.08116615
#  17513.34733537 17515.1898902 ]
# [False False False ... False False False]
# Station: [-31.8   290.707]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [  921.85732764 14653.58614457 14773.21585288 ... 17646.89810299
#  17597.90732311 17599.43419087]
# [False False False ... False False False]
# Station: [-26.84 294.77]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# [ 1165.96657682 14352.65608575 14341.48089255 ... 15607.44695085
#  15556.77496203 15558.09904818]
# [False False False ... False False False]
# Station: [-11.776 282.85 ]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [  423.44934852 14721.02059069 14755.36265778 ... 16406.75275133
#  16355.93399527 16357.22849782]
# [False False False ... False False False]
# Station: [-16.465   288.50702]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [ 1132.69702371 14374.51554363 14365.0831922  ... 15642.2691563
#  15591.58146024 15592.90258951]
# [False False False ... False False False]
# Station: [-11.952 283.124]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [ 1034.74730477 14530.65667728 14525.12360769 ... 15766.45872926
#  15715.55574743 15716.8317418 ]
# [False False False ... False False False]
# Station: [-12.042   284.67902]
# Earthquake periods: (2, 2)
# Normal periods: (81, 2)
#
# (2,)
# [ 1034.74730477 14530.65667728 14525.12360769 ... 15766.45872926
#  15715.55574743 15716.8317418 ]
# [False False False ... False False False]
# Station: [-12.042   284.67902]
# Earthquake periods: (2, 2)
# Normal periods: (81, 2)
#
# (2,)
# [  868.20862149 14408.67501677 14416.09700222 ... 15897.97400578
#  15847.46143643 15848.81325645]
# [False False False ... False False False]
# Station: [-14.089 284.265]
# Earthquake periods: (3, 2)
# Normal periods: (75, 2)
#
# (2,)
# [ 1132.69702371 14374.51554363 14365.0831922  ... 15642.2691563
#  15591.58146024 15592.90258951]
# [False False False ... False False False]
# Station: [-11.952 283.124]
# Earthquake periods: (1, 2)
# Normal periods: (50, 2)
#
# (2,)
# [  749.48005136 14460.25283897 14474.54403531 ... 16018.38406738
#  15967.86276367 15969.21307002]
# [False False False ... False False False]
# Station: [-14.826 285.085]
# Earthquake periods: (10, 2)
# Normal periods: (63, 2)
#
# (2,)
# [ 1989.81201707 14180.53084689 14119.33566059 ... 14808.14353974
#  14757.12047317 14758.36614998]
# [False False False ... False False False]
# Station: [ -5.17  279.361]
# Earthquake periods: (1, 2)
# Normal periods: (51, 2)
#
# (2,)
# [ 9964.65223302 10918.5067962  10606.33754549 ...  7259.4111978
#   7211.44955889  7211.8123285 ]
# [False False False ... False False False]
# Station: [ 62.48  245.518]
# Earthquake periods: (0, 2)
# Normal periods: (52, 2)
#
# (2,)
# Dataset shape: (201, 2)

# %%
catalog = pd.read_csv(r"D:\earthquake-prediction\data\catalog\csv\usgs\2024.csv")
# needs function that extracts the coordinates for each station
station_coords = get_station_coords(ds)
time_period = pd.Timedelta(days=7)
radius = 200
year = 2024

dataset_ranges_by_station = {}
# iterate through each station
id = 0
total_pos = 0
total_neg = 0
for station_coord in station_coords:
    
    # get earthquake periods for station
    eq_periods = get_eq_periods_for_station(
        station_coord=station_coord, 
        catalog=catalog, 
        time_period=time_period, 
        radius=radius)
    # get normal periods for station
    normal_periods = get_normal_periods_for_station(
        eq_periods=eq_periods,
        time_period=time_period, 
        year=year)
    
    # print(f"Station: {station_coord}")
    total_pos += eq_periods.shape[0]
    total_neg += normal_periods.shape[0]

    station_dict = {}
    station_dict["negative"] = normal_periods
    station_dict["positive"] = eq_periods

    # print(station_dict)

    dataset_ranges_by_station[id] = station_dict
    id += 1

print(f"Dataset : {len(dataset_ranges_by_station)}")
print(f"total positive samples: {total_pos}")
print(f"total negative samples: {total_neg}")
# Out:
# Dataset : 201
# total positive samples: 104
# total negative samples: 10738

# %%
time_as_datetime = pd.to_datetime({
    "year": ds["time_yr"].values,
    "month": ds["time_mo"].values,
    "day": ds["time_dy"].values,
    "hour": ds["time_hr"].values,
    "minute": ds["time_mt"].values
})

print(time_as_datetime.shape)
print(time_as_datetime[2])
# Out:
# (527040,)
# 2024-01-01 00:02:00

# %%
def assign_time_as_coordinate(ds: xr.Dataset) -> xr.Dataset:
    time_as_datetime = pd.to_datetime({
        "year": ds["time_yr"].values,
        "month": ds["time_mo"].values,
        "day": ds["time_dy"].values,
        "hour": ds["time_hr"].values,
        "minute": ds["time_mt"].values
    })

    ds = ds.assign_coords(time=("block", time_as_datetime))
    ds = ds.drop_vars(["time_yr", "time_mo", "time_dy", "time_hr", "time_mt"])
    ds = ds.swap_dims({"block": "time"})

    print(ds)

    
    return ds

ds2 = assign_time_as_coordinate(ds)
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:  (time: 527040, vector: 201)
# Coordinates:
#   * time     (time) datetime64[ns] 4MB 2024-01-01 ... 2024-12-31T23:59:00
# Dimensions without coordinates: vector
# Data variables: (12/18)
#     dbe_geo  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbe_nez  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbn_geo  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbn_nez  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbz_geo  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     dbz_nez  (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     ...       ...
#     mlat     (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     mlon     (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     mlt      (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     npnt     (time) int32 2MB dask.array<chunksize=(527040,), meta=np.ndarray>
#     sza      (time, vector) float32 424MB dask.array<chunksize=(296940, 113), meta=np.ndarray>
#     time_sc  (time) float64 4MB dask.array<chunksize=(527040,), meta=np.ndarray>
# Attributes:
#     description:  For the ground magnetometer data we gratefully acknowledge:...

# %%
def extract_multiple_segments(
        sample_ranges: np.ndarray,
        geomag: xr.Dataset,
        station_idx: int,
        label: int) -> xr.Dataset:

    geomag = geomag.isel(vector=station_idx)
    segments = [geomag.sel(time=slice(start, end)).expand_dims(sample=[f"station: {station_idx}, label: {label}, idx: {i}"]) 
                for i, (start, end) in enumerate(sample_ranges)]
    
    # Concatenate along the new "sample" dimension
    ds = xr.concat(segments, dim="sample")

    if ds is not None:
        # ds= ds.assign_coords(sample=("sample", np.arange(len(sample_ranges))))
        ds = ds.assign({"labels": ("sample", np.full(len(sample_ranges), label, dtype=int))})

    return ds

ranges = np.array([
    [pd.Timestamp("2024-01-01 02:00"), pd.Timestamp("2024-01-01 04:00")],  # First segment
    [pd.Timestamp("2024-01-01 07:00"), pd.Timestamp("2024-01-01 09:00")]   # Second segment
])


# Extract separate time segments
pos_ds = extract_multiple_segments(geomag=ds2, sample_ranges=ranges, label= 1, station_idx=0)
neg_ds = extract_multiple_segments(geomag=ds2, sample_ranges=ranges, label= 0, station_idx=0)
if pos_ds is not None and neg_ds is not None:
    combined_ds = xr.concat([pos_ds, neg_ds], dim="sample")
elif pos_ds is not None:
    combined_ds = pos_ds
elif neg_ds is not None:
    combined_ds = neg_ds
else:
    raise ValueError("No valid time ranges provided.")

print(combined_ds)
# Out:
# <xarray.Dataset> Size: 87kB
# Dimensions:  (sample: 4, time: 242)
# Coordinates:
#   * time     (time) datetime64[ns] 2kB 2024-01-01T02:00:00 ... 2024-01-01T09:...
#   * sample   (sample) object 32B 'station: 0, label: 1, idx: 0' ... 'station:...
# Data variables: (12/19)
#     dbe_geo  (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     dbe_nez  (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     dbn_geo  (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     dbn_nez  (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     dbz_geo  (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     dbz_nez  (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     ...       ...
#     mlon     (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     mlt      (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     npnt     (sample, time) float64 8kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     sza      (sample, time) float32 4kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     time_sc  (sample, time) float64 8kB dask.array<chunksize=(1, 121), meta=np.ndarray>
#     labels   (sample) int64 32B 1 1 0 0
# Attributes:
#     description:  For the ground magnetometer data we gratefully acknowledge:...
